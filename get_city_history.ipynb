# %%
from pysus.online_data.Infodengue import download

# %%
osasco = download('dengue', '200001', '202312', 'Osasco')
osasco = osasco.transpose()
# to understand the data, access the site https://info.dengue.mat.br/services/tutorial/Python
osasco.head()
# Out:
#         data_iniSE casos_est casos_est_min casos_est_max casos     p_rt1  \
# SE
# 202312  2023-03-19     140.0           140           140   140  0.995852
# 202311  2023-03-12     106.0           106           106   106  0.934226
# 202310  2023-03-05     102.0           102           102   102  0.990279
# 202309  2023-02-26      90.0            90            90    90  0.990551
# 202308  2023-02-19      62.0            62            62    62  0.881663
# ...            ...       ...           ...           ...   ...       ...
# 201005  2010-01-31       7.0             7             7     7       0.0
# 201004  2010-01-24       3.0             3             3     3       0.0
# 201003  2010-01-17       2.0             2             2     2       0.0
# 201002  2010-01-10      11.0            11            11    11       0.0
# 201001  2010-01-03       0.0             0             0     0       0.0
#
#         p_inc100k Localidade_id nivel                  id  ...    umidmed  \
# ...

# %%
osasco.to_csv('osasco_dengue.csv')
